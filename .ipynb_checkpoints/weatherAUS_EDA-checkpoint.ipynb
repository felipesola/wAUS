# %% [markdown]
# # Importing Libraries
#
# Importing the main libraries for EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset
#
# Import the data set with the data treated in the collection-cleaning step

# %%
df = pd.read_csv('weatherAUS_collection-cleaning.csv')
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.8       8.4
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.8       8.4
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.8       8.4
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.8       8.4
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.8       8.4
# 5  2008-12-06   Albury     14.6     29.7       0.2          4.8       8.4
# 6  2008-12-07   Albury     14.3     25.0       0.0          4.8       8.4
# 7  2008-12-08   Albury      7.7     26.7       0.0          4.8       8.4
# 8  2008-12-09   Albury      9.7     31.9       0.0          4.8       8.4
# 9  2008-12-10   Albury     13.1     30.1       1.4          4.8       8.4
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure3pm  Cloud9am  Cloud3pm  \
# 0           W           44.0          W  ...      1007.1       8.0       5.0
# 1         WNW           44.0        NNW  ...      1007.8       5.0       5.0
# 2         WSW           46.0          W  ...      1008.7       5.0       2.0
# 3          NE           24.0         SE  ...      1012.8       5.0       5.0
# 4           W           41.0        ENE  ...      1006.0       7.0       8.0
# 5         WNW           56.0          W  ...      1005.4       5.0       5.0
# 6           W           50.0         SW  ...      1008.2       1.0       5.0
# 7           W           35.0        SSE  ...      1010.1       5.0       5.0
# 8         NNW           80.0         SE  ...      1003.6       5.0       5.0
# 9           W           28.0          S  ...      1005.7       5.0       5.0
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Month  Year  Day
# 0     16.9     21.8         No            No     12  2008    1
# 1     17.2     24.3         No            No     12  2008    2
# 2     21.0     23.2         No            No     12  2008    3
# 3     18.1     26.5         No            No     12  2008    4
# 4     17.8     29.7         No            No     12  2008    5
# 5     20.6     28.9         No            No     12  2008    6
# 6     18.1     24.6         No            No     12  2008    7
# 7     16.3     25.5         No            No     12  2008    8
# 8     18.3     30.2         No           Yes     12  2008    9
# 9     20.1     28.2        Yes            No     12  2008   10
#
# [10 rows x 26 columns]

# %% [markdown]
# # Histogram
#
# Ploting the histogram to compare with the one with missing values

# %%
#Setting histogram charts

df.hist(figsize=(12, 8))
plt.subplots_adjust(hspace=0.6)
plt.show()

# %% [markdown]
# # Stripplot of all data
# This is to visualy understand how numerical data is distributed

# %%
plt.figure(figsize = (12,8))
sns.stripplot(data = df, orient='h', palette='mako', jitter = False, size = 1.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Boxplot
#
# Of every column

# %%
#Setting boxplot chart

plt.figure(figsize = (12,8))
sns.boxplot(data = df, orient = 'h', fliersize = 1, linewidth = 0.5, palette='mako')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plots
#
# Make some analysis with scatter plots

# %%
#Just to make it easy to copy and past

numerical = df.select_dtypes(include=['float64']).columns
numerical
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm'],
#       dtype='object')

# %%
#Setting 'Humidity3pm' scatter

#relplot
#stripplot

plt.figure(figsize = (12,8))
sns.stripplot(data = df, 
              x='Month', 
              y='Humidity3pm', 
              hue="RainTomorrow", 
              jitter = True, 
              dodge = True, 
              size = 1.5, 
              palette='mako')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Humidity3pm'>

# %% [markdown]
# Here we can see that if the 'Humidity3pm' column value surpass the value 60 it is likely to rain in the next day
